# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardWang11/ECommerceCrawlers/blob/master/markov_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install markovify
# Out:
# Collecting markovify
#   Downloading markovify-0.9.4.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Collecting unidecode (from markovify)
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 5.0 MB/s eta 0:00:00
# Building wheels for collected packages: markovify
#   Building wheel for markovify (setup.py) ... done
#   Created wheel for markovify: filename=markovify-0.9.4-py3-none-any.whl size=18607 sha256=0d0c2a37e3fb5aad19cb058b8c5ab60470865eb0725c089a540796104db1ed8a
#   Stored in directory: /root/.cache/pip/wheels/ca/8c/c5/41413e24c484f883a100c63ca7b3b0362b7c6f6eb6d7c9cc7f
# Successfully built markovify
# Installing collected packages: unidecode, markovify
# Successfully installed markovify-0.9.4 unidecode-1.3.8

# %%
import os
os.chdir('/content/drive/MyDrive/markov_copus')
# !pwd
# Out:
# /content/drive/MyDrive/markov_copus

# %% [markdown]
# **Load dataset from english book**

# %%
# !wget https://www.gutenberg.org/cache/epub/74979/pg74979.txt
# Out:
# --2024-12-28 12:47:03--  https://www.gutenberg.org/cache/epub/74979/pg74979.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1388652 (1.3M) [text/plain]
# Saving to: ‘pg74979.txt’
#
# pg74979.txt         100%[===================>]   1.32M  1.10MB/s    in 1.2s
#
# 2024-12-28 12:47:06 (1.10 MB/s) - ‘pg74979.txt’ saved [1388652/1388652]

# %% [markdown]
# **Training on IMDB**

# %%
### test On IMDB########
import os
import markovify

# Base path to your dataset
base_path = "/content/drive/MyDrive/markov_copus/dataset/aclImdb/train"
directories = ["pos", "neg", "unsup"]

# Initialize the combined Markov model as None
combined_model = None

# Function to read files safely
def safe_read_file(file_path):
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            text = f.read().strip()
            if not text:  # Skip empty files
                print(f"Skipped empty file: {file_path}")
                return None
            return text
    except Exception as e:
        print(f"Error reading file {file_path}: {e}")
        return None

# Loop through the directories and process each file
for directory in directories:
    dir_path = os.path.join(base_path, directory)
    for file_name in os.listdir(dir_path):
        if file_name.endswith(".txt"):
            file_path = os.path.join(dir_path, file_name)
            text = safe_read_file(file_path)
            if text:
                try:
                    # Use NewlineText for better sentence handling
                    model = markovify.NewlineText(text, retain_original=False)
                    # Combine the models
                    if combined_model:
                        combined_model = markovify.combine(models=[combined_model, model])
                    else:
                        combined_model = model
                except KeyError as e:
                    # Handle files causing `('___BEGIN__', '___BEGIN__')` errors
                    print(f"Skipped problematic file {file_path}: {e}")
                except Exception as e:
                    print(f"Unexpected error processing file {file_path}: {e}")

# Generate sentences from the combined model
if combined_model:
    print("\nGenerated Sentences:")
    for i in range(5):
        sentence = combined_model.make_sentence(tries=100)
        if sentence:
            print(sentence)
        else:
            print("Failed to generate a valid sentence. Try increasing 'tries'.")
else:
    print("No valid text files found or failed to generate the model.")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4208_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3507_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3667_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4159_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4066_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3843_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3752_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4177_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3477_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3860_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3851_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4099_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3656_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3699_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3845_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3609_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3654_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4039_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3661_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4069_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3770_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3833_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3961_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3463_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3838_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3622_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3418_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3975_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4199_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4048_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3593_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4024_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3702_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3466_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3644_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4080_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3812_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3940_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3767_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3782_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3846_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3966_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3893_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3701_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3759_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4154_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3571_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4016_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3941_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3448_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3866_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3693_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3898_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3797_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3400_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3627_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3557_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3965_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3784_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3664_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4105_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3636_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3698_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3939_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3513_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3988_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3777_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3793_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3753_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4023_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3569_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3972_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3543_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3646_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3456_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3621_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4097_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3932_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3726_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3469_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4058_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4057_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3822_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3417_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3842_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4068_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3650_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4035_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3911_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3880_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4186_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4202_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3976_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4065_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3544_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3971_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3563_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4051_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3453_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4201_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3850_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3778_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3950_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4053_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3942_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3896_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3470_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3660_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4116_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3717_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4125_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3679_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3423_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4210_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4138_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4153_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3491_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3541_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3718_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3887_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3710_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3983_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3666_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3437_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3653_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3586_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3440_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3769_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3738_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3968_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3982_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3442_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3886_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3809_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3421_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4169_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3814_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4104_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4027_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3458_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3855_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4143_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3495_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3762_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3529_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3445_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4062_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4195_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3695_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3731_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3497_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4140_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4144_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3818_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3651_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/4155_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3432_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3832_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3969_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/3987_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1562_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1961_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1876_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1708_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1474_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2071_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1809_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1761_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1445_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1486_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1778_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1570_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1832_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1517_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1568_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1585_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1964_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1896_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1742_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1725_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1602_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1574_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1707_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1889_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1927_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2036_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1580_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1593_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1659_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1471_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2002_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1543_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1446_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1617_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2070_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1679_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1485_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1882_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1954_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1721_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1919_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1547_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2016_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1527_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1968_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1891_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1466_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1857_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1892_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1504_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1916_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1979_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1529_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1840_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1982_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1586_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1581_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1829_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1801_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2029_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1945_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1702_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1495_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1677_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1481_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1554_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1451_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1621_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1969_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2031_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2046_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1890_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2030_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2054_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1532_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1779_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1680_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1902_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1542_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1784_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1632_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1713_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1962_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1776_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1879_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1845_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1993_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1767_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1871_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1790_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1777_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1930_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1569_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1654_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1849_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1624_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1476_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1558_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1877_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1900_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1736_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1814_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1473_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1468_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1756_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1625_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2007_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1690_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1548_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2057_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1629_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1643_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1831_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1864_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1700_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1672_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1525_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1873_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1592_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2033_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1752_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1844_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1678_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2079_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2020_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1757_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2028_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1716_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1652_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1687_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1947_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1590_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1483_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1477_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1648_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1642_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1701_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2078_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1718_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1774_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1795_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2063_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1539_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1656_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1447_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1553_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1741_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1505_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1755_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1988_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1899_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1850_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1976_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1535_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1457_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1766_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1912_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1923_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1448_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1797_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1862_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1789_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1549_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1715_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1921_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1469_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1709_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1956_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1865_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2074_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1860_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1587_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1987_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1697_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1943_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2017_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2055_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2067_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1667_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1599_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1689_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1895_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1867_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1853_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2013_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1560_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2041_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1839_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1780_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2048_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1671_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1733_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1870_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1827_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1688_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1897_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1706_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2008_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1975_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2006_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1582_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2042_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1824_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1696_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1572_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/2015_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1946_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1770_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/1663_0.txt: ('___BEGIN__', '___BEGIN__')
# ...
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21300_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21299_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21298_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21297_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21296_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21295_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21294_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21292_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21290_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21288_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21287_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21286_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21285_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21284_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21282_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21281_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21280_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21279_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21278_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21277_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21276_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21273_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21271_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21270_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21269_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21268_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21267_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21266_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21265_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21264_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21263_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21262_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21261_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21260_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21259_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21258_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21257_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21256_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21254_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21253_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21252_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21251_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21250_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21249_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21248_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21503_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21502_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21501_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21499_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21498_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21497_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21495_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21494_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21493_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21492_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21489_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21486_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21485_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21484_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21483_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21482_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21480_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21479_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21476_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21475_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21474_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21473_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21471_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21470_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21467_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21466_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21465_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21464_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21463_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21462_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21461_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21460_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21458_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21457_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21456_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21454_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21453_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21452_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21450_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21449_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21448_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21447_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21446_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21445_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21444_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21442_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21441_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21440_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21439_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21438_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21437_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21436_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21433_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21432_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21431_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21430_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21428_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21427_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21426_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21425_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21424_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21423_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21422_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21421_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21420_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21418_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21417_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21416_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21415_0.txt: ('___BEGIN__', '___BEGIN__')
# Skipped problematic file /content/drive/MyDrive/markov_copus/dataset/aclImdb/train/unsup/21414_0.txt: ('___BEGIN__', '___BEGIN__')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-2a62232d93e4> in <cell line: 25>()
#      35                     # Combine the models
#      36                     if combined_model:
# ---> 37                         combined_model = markovify.combine(models=[combined_model, model])
#      38                     else:
#      39                         combined_model = model
#
# /usr/local/lib/python3.10/dist-packages/markovify/utils.py in combine(models, weights)
#      45             for subseq_k, subseq_v in options.items():
#      46                 subseq_prev = current.get(subseq_k, 0)
# ---> 47                 current[subseq_k] = subseq_prev + (subseq_v * w)
#      48             c[state] = current
#      49
#
# KeyboardInterrupt:

# %%
# Print three randomly-generated sentences of no more than 280 characters
for i in range(3):
    print(text_model.make_short_sentence(280))
# Out:
# I did so, my thirst for the end.
# Weena’s distress, I reached almost immediately the Morlocks and repugnance of ruined masonry.
# But here and as I tried to me giddy.

# %%
with open("/content/drive/MyDrive/markov_copus/dataset/aclImdb/train/pos/10093_7.txt") as f:
  text = f.read()
print(text)
# Out:
# A beautiful shopgirl in London is swept off her feet by a millionaire tea plantation owner and soon finds herself married and living with him at his villa in British Ceylon. Although based upon the book by Robert Standish, this initial set-up is highly reminiscent of Hitchock's "Rebecca", with leading lady Elizabeth Taylor clashing with the imposing chief of staff at the mansion and (almost immediately) her own husband, who is still under the thumb of his deceased-but-dominant father. Taylor, a last-minute substitute for an ailing Vivien Leigh, looks creamy-smooth in her high fashion wardrobe, and her performance is quite strong; however, once husband Peter Finch starts drinking heavily and barking orders at her, one might think her dedication to him rather masochistic (this feeling hampers the ending as well). Still, the film offers a heady lot for soap buffs: romantic drama, a bit of travelogue, interpretive dance, an elephant stampede, and a perfectly-timed outbreak of cholera! *** from ****

# %%
import torch
import torch.nn as nn
import random
import json
from bisect import bisect
from collections import defaultdict
from typing import List, Dict, Union, Tuple


BEGIN = "___BEGIN__"
END = "___END__"


class MarkovChain:
    """
    A class for creating and using a Markov Chain model.
    """
    def __init__(self, order: int, data: List[List[str]]):
        self.order = order
        self.data = data
        self.model = defaultdict(lambda: defaultdict(int))
        self._build_model()

    def _build_model(self, ):
        """Builds the Markov Chain model from the given data."""
        for sentence in self.data: # 假设句子之间用空格分隔
            words = ([BEGIN] * self.order) + sentence + [END]
            for i in range(len(words) - self.order):
                state = tuple(words[i:i+self.order])
                next_state = words[i+self.order]
                self.model[state][next_state] += 1

        for state in self.model:
            total = sum(self.model[state].values())
            for next_state in self.model[state]:
                self.model[state][next_state] /= total

    def generate(self, length: int, start: Union[str, None] = None) -> List[str]:
        """Generates a sequence of states of the given length."""
        if start is None:
            start = random.choice(list(self.model.keys()))
        else:
            start = tuple(start[-self.order:])

        result = list(start)
        for _ in range(length - self.order):
            next_state = self._sample_next_state(start)
            result.append(next_state)
            start = tuple(result[-self.order:])

        return result

    def _sample_next_state(self, state: Tuple[str]) -> str:
        """Samples the next state based on the probabilities in the model."""
        probabilities = list(self.model[state].values())
        states = list(self.model[state].keys())
        return random.choices(states, probabilities)[0]

    def save_model(self, file_path: str):
        with open(file_path, 'w', encoding='utf-8') as f:
            json.dump(self.model, f, ensure_ascii=False, indent=4)

    @classmethod
    def load_model(self, file_path: str):
        with open(file_path, 'r', encoding='utf-8') as f:
            self.model = json.load(f)


# Example usage
if __name__ == "__main__":
    # 示例数据，这里简单模拟了一些单词组成的序列，实际应用中可以从文件读取文本并进行分词等处理来获取更丰富的数据
    data = [["the", "cat", "runs", "quickly", "the", "dog", "walks", "slowly", "the", "bird", "flies", "high"]]
    # 创建马尔可夫链模型实例，设置阶数为2
    markov_chain = MarkovChain(2, data)

    # 使用模型生成一个长度为10的新序列，不指定起始状态（将随机选择起始状态）
    generated_sequence = markov_chain.generate(5)
    print(generated_sequence)
# Out:
# ['quickly', 'the', 'dog', 'walks', 'slowly']

# %%
## 评价生成的句子 评价指标bleu
from evaluation import evaluate_bleu

if __name__ == "__main__":
    # 示例参考句子（可以替换为你的参考句子）
    reference_sentences = [
        "Those waterless wells must have been dry for years.",
        "I thought of the ghost on the green hill stirring in the wind.",
        "I could find no sign of life anywhere in the ruins.",
        "The ebook is now available for free, and can be downloaded easily.",
        "There is very little light in this room, and it is hard to see."
    ]

    # 示例生成句子（可以替换为生成的句子）
    generated_sentences = [
        "Those waterless wells, must have read, I seemed tricks in the strength of his mind.",
        "I thought of the ghost for the green of the stir of it takes a click and had nothing on the subsiding red joint I stooped to light of agriculture; the mantel and open hill.",
        "I could find no wasting my mind came blundering into a Morlock or dried grass of yore.",
        "This ebook is now, and, as a steady twilight brooded over to provide a foolish moment, and startling some carnal cravings, I would amaze our position.",
        "There is very little people came a peculiar manner, to the tension by their eyes."
    ]

    # 调用 evaluate_bleu 函数计算 BLEU 分数
    bleu_scores, average_bleu = evaluate_bleu(reference_sentences, generated_sentences)

    # 输出每个句子的 BLEU 分数
    print("BLEU Scores for each sentence:")
    for i, score in enumerate(bleu_scores):
        print(f"Sentence {i + 1}: {score:.4f}")

    # 输出平均 BLEU 分数
    print(f"\nAverage BLEU Score: {average_bleu:.4f}")
# Out:
# BLEU Scores for each sentence:
# Sentence 1: 0.0395
# Sentence 2: 0.1267
# Sentence 3: 0.1514
# Sentence 4: 0.0170
# Sentence 5: 0.1740
#
# Average BLEU Score: 0.1017

# %%
# !pip install datasets
# !pip install rouge
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge) (1.17.0)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %% [markdown]
# **Preprocessing**
#
#
# *   *Observations:*
# 1. Unnecessary Markers:
#
# Section markers like = Missouri River =, = Major tributaries =, or = = = ... = = = should be removed.
# 2. Extra Spaces:
#
# There are redundant spaces around punctuation and between words, which need to be normalized.
# 3. Structured Information:
#
# Some content is in a structured, encyclopedic format (e.g., lists or detailed descriptions). Depending on your task, you might want to remove sections with excessive detail (like lists or tables) or retain only the narrative content.
# 4. Punctuation Artifacts:
#
# The text is generally clean of tokenization artifacts, but formatting (like numbers and units) could be normalized for consistency.
# *   *Goals*
# 1. Remove unnecessary section markers.
# 2. Normalize spaces and punctuation.
# 3. Keep the text in a natural narrative form.

# %%
import re

def clean_wikitext(text):
    """
    Cleans Wikitext data for modeling or evaluation.
    - Removes section headers (e.g., "= Section =").
    - Normalizes spaces and line breaks.
    - Optionally removes non-narrative content like tables or lists.
    Args:
        text (str): The raw input text.
    Returns:
        str: The cleaned text.
    """
    # Remove section headers (e.g., "= Section =")
    text = re.sub(r'=+\s*.*?\s*=+', '', text)

    # Replace multiple spaces/newlines with a single space
    text = re.sub(r'\s+', ' ', text).strip()

    # (Optional) Normalize punctuation (remove extra spaces around punctuation)
    text = re.sub(r'\s([?.!,;:\'\"])', r'\1', text)  # Remove space before punctuation
    text = re.sub(r'([?.!,;:\'\"])\s', r'\1 ', text)  # Ensure space after punctuation
    text = re.sub(r'\s+', ' ', text).strip()  # Final space normalization

    return text


# # Apply the cleaning function to a sample text
# raw_text = """
# = = = Air support and logistics = = =

# Aerial operations for the incursion got off to a slow start . Reconnaissance flights over the operational area were restricted since MACV believed that they might serve as a signal of intention . The role of the Air Force in the planning for the incursion itself was minimal at best , in part to preserve the secrecy of Menu which was then considered an overture to the thrust across the border .
# """

# cleaned_text = clean_wikitext(raw_text)
# print(cleaned_text)

# %% [markdown]
# **Load Dataset from wikiText**

# %%
from datasets import load_dataset

# Load the Wikitext-2-raw-v1 dataset
dataset = load_dataset("Salesforce/wikitext", "wikitext-2-raw-v1")

cleaned_train_data = [clean_wikitext(example['text']) for example in dataset['train']]
cleaned_val_data = [clean_wikitext(example['text']) for example in dataset['validation']]
cleaned_test_data = [clean_wikitext(example['text']) for example in dataset['test']]
# Save the cleaned splits to text files
with open("cleaned_train.txt", "w") as f:
    for line in cleaned_train_data:
        f.write(line + "\n")
with open("cleaned_validation.txt", "w") as f:
    for line in cleaned_val_data:
        f.write(line + "\n")

with open("cleaned_test.txt", "w") as f:
    for line in cleaned_test_data:
        f.write(line + "\n")
# Print examples from each cleaned split
print("Cleaned Train Example:", cleaned_train_data[3])
# Out:
# Cleaned Train Example: Senjō no Valkyria 3: Unrecorded Chronicles ( Japanese: 戦場のヴァルキュリア3, lit. Valkyria of the Battlefield 3 ), commonly referred to as Valkyria Chronicles III outside Japan, is a tactical role @-@ playing video game developed by Sega and Media.Vision for the PlayStation Portable. Released in January 2011 in Japan, it is the third game in the Valkyria series. Employing the same fusion of tactical and real @-@ time gameplay as its predecessors, the story runs parallel to the first game and follows the" Nameless", a penal military unit serving the nation of Gallia during the Second Europan War who perform secret black operations and are pitted against the Imperial unit" Calamaty Raven".

# %%
# Iterate over the training data
for example in cleaned_train_data:
    print(example)  # Each example contains a 'text' field

# %%
import markovify

# Load the cleaned text with sentences on new lines
with open("/content/drive/MyDrive/markov_copus/dataset/wikiText/cleaned_train.txt", "r") as f:
    text = f.read()

# Build the Markovify model using NewlineText
text_model = markovify.NewlineText(text)

# Print generated sentences
print("Randomly generated sentences:")
for i in range(5):
    print(text_model.make_sentence())
# # Print three randomly-generated sentences of no more than 280 characters
print("\nRandomly generated short sentences:")
for i in range(3):
    print(text_model.make_short_sentence(280))
# Out:
# Randomly generated sentences:
# East Carolina had been phased out since 1969.
# In 1999, at the Groesbeek Memorial. Major Robert Henry Cain, also of 2nd Battalion, 27th Infantry Regiment, in at the elite level, although they take him back. Daisuke Aramaki, head of the estuary of national debt, prejudicial trade policies by other sequences. For instance, Khnum was the third disc. It also made minor appearances.
# syān @-@ nāsti @-@ avaktavyaḥ — in the top flight performers, but City were relegated with Notts County manager, Lawton ran the Ministries of Labor and Health, founded and ran the ball shoots one free throw line and then deal with the development of a large parsonage in Mechtshausen. Busch read biographies, novels and stories of fox possession still occur, such as UV Ceti may also have a polygynous lek breeding system. It is sedentary over its lifetime, all designed by Timothy L. Pflueger in the teachings of Mahāvīra, who used it for its return. For example, he would do in Congress on their robes at all of these pressures, the IUCN Red List species as of 1 @,@ 250 were buried within a vacuum cleaner pipe serves as the fly agaric or fly amanita, is a cross @-@ examine witnesses, and to produce peptides in high school and rugby union team represents the story's serious tone. Points criticized in the UK and PBS in the Shell remake is scheduled to be a day @-@ to @-@ day disabled list upon signing to continue coaching youth baseball camps and units were transferred to Townsville for the first water @-@ borne stomach diseases.
# The soldiers keenly listen to the playoffs in 1943 as Maidan Castle, Dorset. The report's publication allowed further criticism to be in search of Shiva to atone for their June 3 @-@ test series against Germany. She was credited with hits on several occasions in prose. Stanley Woolley, a character in the League Cup tie against Reading, scoring just two qualifying games for the J @-@ pop phenomenon.
# A map of all cancer deaths in New York. When the NY 312 designation was shifted south to the grievance or dishonour of the water; by 02: 20, the screws and both ambulances arrived in Alexandria, Egypt on 11 December. On 30 April, and another from Nîmes.
#
# Randomly generated short sentences:
# Throughout the rest of the cabinet, the white monopoly on offshore flights. However, the British ship, inflicting significant damage to the 1980s.
# A Confession of Faith to replace him, and his companions moved throughout the NBA and appeared on the British paratroopers. At the start vertex of the bypass tunnels, as the case is solved.
# At 05: 30 on 7 October 1987. She carried the ship's cargo was loaded in Greenock in early 1229 to conclude negotiations with envoys of the athletes. If the athlete should not be recognized immediately, because the parasite infects and sterilizes the eggs of the magazine.

# %% [markdown]
# **Evaluation with BLEU score**:
# The BLEU (Bilingual Evaluation Understudy) score measures how closely the generated sentences match reference sentences.

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
import markovify

# Load the cleaned reference text (validation or test data)
with open("/content/drive/MyDrive/markov_copus/dataset/wikiText/cleaned_test.txt", "r") as f:
    reference_sentences = f.readlines()

# Load the Markov model
with open("/content/drive/MyDrive/markov_copus/dataset/wikiText/cleaned_train.txt", "r") as f:
    text = f.read()
text_model = markovify.NewlineText(text)

# Generate sentences using the Markov model
generated_sentences = [text_model.make_sentence() for _ in range(10)]

# Evaluate BLEU score
smoothing_function = SmoothingFunction().method1  # To handle edge cases
bleu_scores = []

for gen_sentence in generated_sentences:
    if gen_sentence:  # Ignore None outputs
        # Use all reference sentences to calculate BLEU score for each generated sentence
        references = [ref.split() for ref in reference_sentences]
        gen_tokens = gen_sentence.split()
        score = sentence_bleu(references, gen_tokens, smoothing_function=smoothing_function)
        bleu_scores.append(score)

# Print the BLEU scores for each generated sentence
print("Generated Sentences and BLEU Scores:")
for i, (gen_sentence, score) in enumerate(zip(generated_sentences, bleu_scores)):
    print(f"Sentence {i + 1}: {gen_sentence}")
    print(f"BLEU Score: {score:.4f}")

# Calculate the average BLEU score
avg_bleu = sum(bleu_scores) / len(bleu_scores) if bleu_scores else 0
print(f"\nAverage BLEU Score: {avg_bleu:.4f}")
# Out:
# Generated Sentences and BLEU Scores:
# Sentence 1: Many federal groups at 100 McAllister served as headquarters of the most problematic and worst @-@ sounding to the formation of the record. Federer turned the tide at the gravesite of Edward II led to her by impaling her through the proportional representation with the management's artistic freedom, but Olivier himself stayed firmly in place, but little was done with three grade As. From there Pryce went on to win the game.
# BLEU Score: 0.1629
# Sentence 2: Some original costumes were designed by H. R. Giger, also responsible for porting the Guitar Hero games is a side @-@ scrolling platform video game, the player shooting the free kick, Alabama scored on a one @-@ hour duel, sailing at 11: 20 they were unique Astraeus species, including sub @-@ districts have pending AOC applications to become the subject matter or the Sun.
# BLEU Score: 0.0784
# Sentence 3: In June 1877, at the route's northern terminus. This construction consisted of former Looking Glass employees.
# BLEU Score: 0.0596
# Sentence 4: More generally, ancient Egyptians seem to have been identified, including: other blood disorders, chemical exposures, ionizing radiation, and genetics.
# BLEU Score: 0.0938
# Sentence 5: The French Atlantic Fleet.
# BLEU Score: 0.2021
# Sentence 6: Regarded throughout his career and became their inaugural marquee player; with his parents to children which include:
# BLEU Score: 0.2329
# Sentence 7: Attempt to found what is now one of the games. In November 2006, joining Rushden & Diamonds. He then reached NC State by two massive stone structures, which resemble titla. Because writing materials such as faeces or dead nestlings. Protozoan blood parasites of the blood of smokers is 4 times greater nitrosamine exposure from food and providing for the charity Acorns Children's Hospice, the first @-@ down type output terminals; later models had screw terminals.
# BLEU Score: 0.0585
# Sentence 8: By this time he was elected as a hunting trip in the bandit cart and kill frozen zombies before they captured Tianzuo, the last season of excavation and recording. Further, he is shocked to see such former footballers as George Best and Kevin Keegan. In 2015, Stansfield was diagnosed with a scene which is around 7 per cent budget increase for the chapters. He eventually abandoned and the All @-@ ACC receiver Nasrallah Worthen, who led the Hokies during their shows. These link @-@ ups late in 1908, with Benson's encouragement. A correspondence ensued and in the field. After a bad snap. After the fall in 36 games in the burial record of Thomas Pynchon's 2009 novel Inherent Vice
# BLEU Score: 0.1653
# Sentence 9: In the Fastra II's predecessor, the Fastra II was later adapted into a remnant low.
# BLEU Score: 0.1138
# Sentence 10: Aside from humans, no species preys upon mature cougars in the early days of the village of Bình Giã from the southwest. At the same reachability relation described by David Conway
# BLEU Score: 0.2992
#
# Average BLEU Score: 0.1466

# %% [markdown]
# **Evaluation with ROUGE Scores:**
#
# ROUGE-1: Measures overlap of unigrams (single words).
# ROUGE-2: Measures overlap of bigrams (two-word sequences).
# ROUGE-L: Measures the longest common subsequence (LCS) between the generated and reference texts.

# %%
from rouge import Rouge
import markovify

# Load the reference sentences from the validation or test file
with open("/content/drive/MyDrive/markov_copus/dataset/wikiText/cleaned_test.txt", "r") as f:
    reference_sentences = f.readlines()

# Load the cleaned training text for Markovify
with open("/content/drive/MyDrive/markov_copus/dataset/wikiText/cleaned_train.txt", "r") as f:
    text = f.read()

# Build the Markovify model
text_model = markovify.NewlineText(text)

# Generate sentences using the Markov model
generated_sentences = [text_model.make_sentence() for _ in range(5)]

# Initialize the ROUGE scorer
rouge = Rouge()

# Evaluate ROUGE scores for each generated sentence
print("Generated Sentences and ROUGE Scores:")
for i, gen_sentence in enumerate(generated_sentences):
    if gen_sentence:  # Ignore None outputs
        # Compute ROUGE scores for the generated sentence against all references
        scores = rouge.get_scores(gen_sentence, " ".join(reference_sentences), avg=True)
        print(f"Sentence {i + 1}: {gen_sentence}")
        print(f"ROUGE-1 F1: {scores['rouge-1']['f']:.4f}, ROUGE-2 F1: {scores['rouge-2']['f']:.4f}, ROUGE-L F1: {scores['rouge-l']['f']:.4f}\n")
# Out:
# Generated Sentences and ROUGE Scores:
# Sentence 1: On 27 August 1907, a gas @-@ filled maze. Major streets were cleared or rejected on a misinterpretation of history and cultural events. Major government buildings are churches built before the year was a success, finishing as the Cardiff International Pool, Cardiff International White Water and Gordon was arrested on suspicion of murder at 8.00am the next film as a boulevard, a type of thing. The dedication ceremony was attended by 1 @,@ 076 hectare Roderick Haig @-@ Brown Provincial Park and fort today
# ROUGE-1 F1: 0.0041, ROUGE-2 F1: 0.0005, ROUGE-L F1: 0.0041
#
# Sentence 2: Hoover Dam, once known as a front line the northern bases was day after the earthquake @-@ ravaged city.
# ROUGE-1 F1: 0.0012, ROUGE-2 F1: 0.0002, ROUGE-L F1: 0.0012
#
# Sentence 3: The song is an example of a covenant offered by God to the south and Port Elizabeth. It is unusual for track and field as it moved southwestward. The very high encounter rate, and was moderately religious. He earned a bachelor's degree in English and French warships were in danger from storm surge.
# ROUGE-1 F1: 0.0032, ROUGE-2 F1: 0.0005, ROUGE-L F1: 0.0031
#
# Sentence 4: This movement is prompted by the Turks back over the stumps or struck them. The Commission chose the United Kingdom in the semifinals and advance into the sea coast while the 3000 m is held at York Racecourse, Oyebanjo was voted the Finals MVP, having led all scorers averaging 33 @.@ 5 %. On January 31, 1861
# ROUGE-1 F1: 0.0033, ROUGE-2 F1: 0.0004, ROUGE-L F1: 0.0033
#
# Sentence 5: In 1983, it held approximately 7 % of to the route runs due east through Europe to control both Hum and Dubrava counties, which incorporated much of the freeway saw increased traffic. Wilson Avenue experienced a large yacht in 1997, and has been certified double platinum. It achieved No. 1 Federer at the top tier of non @-@ FIFA nationality.
# ROUGE-1 F1: 0.0036, ROUGE-2 F1: 0.0003, ROUGE-L F1: 0.0035
